# %% [markdown]
# # Visulalisation

# %%
import pandas as pd
import seaborn as sns

# %%
# Load DataFrame
import pickle
path = './data/df_results.pickle'
with open(path, 'rb') as f:
    df_results = pickle.load(f)

# %%
df_results.index = df_results.index.rename('loss_name', level=4)

# %%
df_results = (df_results.reset_index()
                        .dropna())

# %% [markdown]
# ## Desired format :

# %%
df_results.epsilon.unique()
# Out:
# array([0.00784314, 0.01176471, 0.01568627, 0.01960784, 0.02352941,
#        0.02745098, 0.03137255, 0.03529412])

# %%
# Sanity check
(df_results.epsilon < df_results.eta).sum()
df_results[df_results.epsilon == 0].sum()
# Out:
# method       0.0
# eta          0.0
# epsilon      0.0
# n_steps      0.0
# loss_name    0.0
# loss         0.0
# accuracy     0.0
# dtype: float64

# %%
# Rename PGD n_step == 1 to FGSM
# These are FGSM since FGSM is PGD with n_step =1
mask_fgsm = df_results.n_steps == 1
df_results.loc[mask_fgsm, 'method', ] = (df_results.loc[mask_fgsm, 'method']
                                                       .str
                                                       .replace('pgd', 'fgsm'))

# %%
df_results[df_results.method == 'pgd_l2']
# Out:
#       method       eta   epsilon  n_steps                 loss_name      loss  \
# 1630  pgd_l2  0.003922  0.007843        2        mean_squared_error  0.994069
# 1631  pgd_l2  0.003922  0.007843        2  categorical_crossentropy  0.990194
# 1632  pgd_l2  0.003922  0.007843        4        mean_squared_error  0.994054
# 1633  pgd_l2  0.003922  0.007843        4  categorical_crossentropy  0.990165
# 1634  pgd_l2  0.003922  0.007843        6        mean_squared_error  0.994061
# ...      ...       ...       ...      ...                       ...       ...
# 2333  pgd_l2  0.031373  0.035294        4  categorical_crossentropy  0.881799
# 2334  pgd_l2  0.031373  0.035294        6        mean_squared_error  0.898045
# 2335  pgd_l2  0.031373  0.035294        6  categorical_crossentropy  0.881828
# 2336  pgd_l2  0.031373  0.035294        8        mean_squared_error  0.898087
# 2337  pgd_l2  0.031373  0.035294        8  categorical_crossentropy  0.881828
#
#       accuracy
# 1630    0.7167
# 1631    0.7164
# 1632    0.7167
# 1633    0.7164
# 1634    0.7167
# ...        ...
# 2333    0.7421
# 2334    0.7431
# 2335    0.7421
# 2336    0.7431
# 2337    0.7421
#
# [288 rows x 7 columns]

# %%
g = sns.relplot(x="epsilon", y="accuracy",
                 col="method", hue='loss_name', col_wrap=3,
                 kind="line", data=df_results.reset_index())

# %%
g = sns.relplot(x="n_steps", y="accuracy",
                 col="method", hue='loss_name', col_wrap=3,
                 kind="line", data=df_results.reset_index())

# %%
g = sns.relplot(x="eta", y="accuracy",
                 col="method", col_wrap=3, hue='loss_name',
                 kind="line", data=df_results.reset_index())
